# %%
path = 'frame_interpolation/pretrained_models/film_net/Style/saved_model'
folder = 'photos' #@param {type:"string"}

times = 4 #@param {type:"slider", min:1, max:10, step:1}
fps = 30 #@param {type:"slider", min:1, max:60, step:1}

# %%
# Resize images

import os

for current_path in os.listdir(folder):
    if os.path.isfile(os.path.join(folder, current_path)):
        # !ffmpeg -y -i {folder}/{current_path} -vf scale="800:-1" {folder}/{current_path.replace('jpg', 'jpg')}
# !ffmpeg -i {folder} -vf scale="1000:-1"
# Out:
# ffmpeg version 5.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with clang version 14.0.6
#   configuration: --prefix=/d/bld/ffmpeg_1658802367738/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libfontconfig --enable-libopenh264 --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --pkg-config=/d/bld/ffmpeg_1658802367738/_build_env/Library/bin/pkg-config
#   libavutil      57. 28.100 / 57. 28.100
#   libavcodec     59. 37.100 / 59. 37.100
#   libavformat    59. 27.100 / 59. 27.100
#   libavdevice    59.  7.100 / 59.  7.100
#   libavfilter     8. 44.100 /  8. 44.100
#   libswscale      6.  7.100 /  6.  7.100
#   libswresample   4.  7.100 /  4.  7.100
#   libpostproc    56.  6.100 / 56.  6.100
# photos/WhatsApp: No such file or directory
# ffmpeg version 5.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with clang version 14.0.6
#   configuration: --prefix=/d/bld/ffmpeg_1658802367738/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libfontconfig --enable-libopenh264 --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --pkg-config=/d/bld/ffmpeg_1658802367738/_build_env/Library/bin/pkg-config
#   libavutil      57. 28.100 / 57. 28.100
#   libavcodec     59. 37.100 / 59. 37.100
#   libavformat    59. 27.100 / 59. 27.100
#   libavdevice    59.  7.100 / 59.  7.100
#   libavfilter     8. 44.100 /  8. 44.100
#   libswscale      6.  7.100 /  6.  7.100
#   libswresample   4.  7.100 /  4.  7.100
#   libpostproc    56.  6.100 / 56.  6.100
# photos/WhatsApp: No such file or directory

# %%
print('Interpolating...')
# update! httplib2==0.20.2

# !python -m frame_interpolation.eval.interpolator_cli \
     --pattern {folder} \
     --fps {fps} \
     --model_path {path} \
     --times_to_interpolate {times} \
     --output_video
# Out:
# Interpolating...
# c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\apache_beam\__init__.py:79: UserWarning: This version of Apache Beam has not been sufficiently tested on Python 3.9. You may encounter bugs or missing features.
#   warnings.warn(
# W0813 11:53:40.923654  3680 environments.py:371] Make sure that locally built Python SDK docker image has Python 3.9 interpreter.
# I0813 11:53:40.924659  3680 environments.py:380] Default Python SDK image for environment is apache/beam_python3.9_sdk:2.34.0
# I0813 11:53:40.947684  3680 translations.py:678] ==================== <function annotate_downstream_side_inputs at 0x000001D8353E6F70> ====================
# I0813 11:53:40.947684  3680 translations.py:678] ==================== <function fix_side_input_pcoll_coders at 0x000001D8353EA0D0> ====================
# I0813 11:53:40.947684  3680 translations.py:678] ==================== <function pack_combiners at 0x000001D8353EA5E0> ====================
# I0813 11:53:40.948704  3680 translations.py:678] ==================== <function lift_combiners at 0x000001D8353EA670> ====================
# I0813 11:53:40.948704  3680 translations.py:678] ==================== <function expand_sdf at 0x000001D8353EA820> ====================
# I0813 11:53:40.948704  3680 translations.py:678] ==================== <function expand_gbk at 0x000001D8353EA8B0> ====================
# I0813 11:53:40.948704  3680 translations.py:678] ==================== <function sink_flattens at 0x000001D8353EA9D0> ====================
# I0813 11:53:40.948704  3680 translations.py:678] ==================== <function greedily_fuse at 0x000001D8353EAA60> ====================
# I0813 11:53:40.948704  3680 translations.py:678] ==================== <function read_to_impulse at 0x000001D8353EAAF0> ====================
# I0813 11:53:40.948704  3680 translations.py:678] ==================== <function impulse_to_input at 0x000001D8353EAB80> ====================
# I0813 11:53:40.948704  3680 translations.py:678] ==================== <function sort_stages at 0x000001D8353EADC0> ====================
# I0813 11:53:40.948704  3680 translations.py:678] ==================== <function setup_timer_mapping at 0x000001D8353EAD30> ====================
# I0813 11:53:40.948704  3680 translations.py:678] ==================== <function populate_data_channel_coders at 0x000001D8353EAE50> ====================
# I0813 11:53:40.949685  3680 statecache.py:172] Creating state cache with size 100
# I0813 11:53:40.950654  3680 worker_handlers.py:889] Created Worker handler <apache_beam.runners.portability.fn_api_runner.worker_handlers.EmbeddedWorkerHandler object at 0x000001D8354AD3A0> for environment ref_Environment_default_environment_1 (beam:env:embedded_python:v1, b'')
# I0813 11:53:40.950654  3680 fn_runner.py:607] Running (((ref_AppliedPTransform_Create-directory-names-Impulse_3)+(ref_AppliedPTransform_Create-directory-names-FlatMap-lambda-at-core-py-3222-_4))+(ref_AppliedPTransform_Create-directory-names-Map-decode-_6))+(ref_AppliedPTransform_Process-directories_7)
# 2022-08-13 11:53:41.171445: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-08-13 11:53:41.748328: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5470 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:01:00.0, compute capability: 8.6
# I0813 11:53:45.178657  3680 interpolator_cli.py:155] Generating in-between frames for photos.
# 2022-08-13 11:53:45.436629: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-08-13 11:53:49.155674: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8100
# 2022-08-13 11:53:52.499885: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.65GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-08-13 11:53:52.500454: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.65GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-08-13 11:53:52.745496: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.97GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-08-13 11:53:52.746080: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.97GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-08-13 11:53:53.258777: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.09GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-08-13 11:53:53.259399: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.09GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-08-13 11:53:53.409205: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.01GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-08-13 11:53:53.409959: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.01GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-08-13 11:53:53.503743: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.08GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-08-13 11:53:53.504246: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.08GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-08-13 11:54:13.975350: W tensorflow/core/common_runtime/bfc_allocator.cc:457] Allocator (GPU_0_bfc) ran out of memory trying to allocate 300.00MiB (rounded to 314572800)requested by op StatefulPartitionedCall/StatefulPartitionedCall/predict_flow/StatefulPartitionedCall/lambda_5/PartitionedCall/dense_image_warp/PartitionedCall/interpolate_bilinear/gather-top_right/GatherV2
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2022-08-13 11:54:13.976760: I tensorflow/core/common_runtime/bfc_allocator.cc:1004] BFCAllocator dump for GPU_0_bfc
# 2022-08-13 11:54:13.976945: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (256): 	Total Chunks: 84, Chunks in use: 84. 21.0KiB allocated for chunks. 21.0KiB in use in bin. 3.5KiB client-requested in use in bin.
# 2022-08-13 11:54:13.977443: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (512): 	Total Chunks: 11, Chunks in use: 11. 5.8KiB allocated for chunks. 5.8KiB in use in bin. 5.8KiB client-requested in use in bin.
# 2022-08-13 11:54:13.977868: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (1024): 	Total Chunks: 10, Chunks in use: 10. 10.2KiB allocated for chunks. 10.2KiB in use in bin. 10.0KiB client-requested in use in bin.
# 2022-08-13 11:54:13.978594: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (2048): 	Total Chunks: 9, Chunks in use: 8. 19.5KiB allocated for chunks. 17.0KiB in use in bin. 16.7KiB client-requested in use in bin.
# 2022-08-13 11:54:13.979182: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (4096): 	Total Chunks: 2, Chunks in use: 1. 11.8KiB allocated for chunks. 6.8KiB in use in bin. 6.8KiB client-requested in use in bin.
# 2022-08-13 11:54:13.979611: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (8192): 	Total Chunks: 5, Chunks in use: 5. 46.0KiB allocated for chunks. 46.0KiB in use in bin. 45.5KiB client-requested in use in bin.
# 2022-08-13 11:54:13.979982: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (16384): 	Total Chunks: 1, Chunks in use: 0. 19.0KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-13 11:54:13.980583: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (32768): 	Total Chunks: 11, Chunks in use: 11. 404.0KiB allocated for chunks. 404.0KiB in use in bin. 404.0KiB client-requested in use in bin.
# 2022-08-13 11:54:13.980974: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (65536): 	Total Chunks: 1, Chunks in use: 0. 93.8KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-13 11:54:13.981296: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (131072): 	Total Chunks: 17, Chunks in use: 15. 2.49MiB allocated for chunks. 2.12MiB in use in bin. 2.12MiB client-requested in use in bin.
# 2022-08-13 11:54:13.981669: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (262144): 	Total Chunks: 3, Chunks in use: 2. 1.16MiB allocated for chunks. 742.5KiB in use in bin. 742.5KiB client-requested in use in bin.
# 2022-08-13 11:54:13.982024: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (524288): 	Total Chunks: 15, Chunks in use: 14. 8.87MiB allocated for chunks. 8.28MiB in use in bin. 8.28MiB client-requested in use in bin.
# 2022-08-13 11:54:13.982372: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (1048576): 	Total Chunks: 10, Chunks in use: 8. 11.67MiB allocated for chunks. 9.33MiB in use in bin. 9.33MiB client-requested in use in bin.
# 2022-08-13 11:54:13.982742: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (2097152): 	Total Chunks: 19, Chunks in use: 19. 45.36MiB allocated for chunks. 45.36MiB in use in bin. 45.36MiB client-requested in use in bin.
# 2022-08-13 11:54:13.983035: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (4194304): 	Total Chunks: 10, Chunks in use: 9. 56.95MiB allocated for chunks. 49.91MiB in use in bin. 42.00MiB client-requested in use in bin.
# 2022-08-13 11:54:13.983289: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (8388608): 	Total Chunks: 11, Chunks in use: 10. 123.56MiB allocated for chunks. 108.92MiB in use in bin. 108.92MiB client-requested in use in bin.
# 2022-08-13 11:54:13.983605: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (16777216): 	Total Chunks: 1, Chunks in use: 1. 16.88MiB allocated for chunks. 16.88MiB in use in bin. 16.88MiB client-requested in use in bin.
# 2022-08-13 11:54:13.984066: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (33554432): 	Total Chunks: 1, Chunks in use: 1. 42.93MiB allocated for chunks. 42.93MiB in use in bin. 42.93MiB client-requested in use in bin.
# 2022-08-13 11:54:13.984454: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (67108864): 	Total Chunks: 1, Chunks in use: 1.
I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 524288 totalling 512.0KiB
# 2022-08-13 11:54:14.035183: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 4 Chunks of size 589824 totalling 2.25MiB
# 2022-08-13 11:54:14.035360: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 8 Chunks of size 614400 totalling 4.69MiB
# 2022-08-13 11:54:14.035566: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 884736 totalling 864.0KiB
# 2022-08-13 11:54:14.035762: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 1179648 totalling 1.12MiB
# 2022-08-13 11:54:14.035951: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 7 Chunks of size 1228800 totalling 8.20MiB
# 2022-08-13 11:54:14.036151: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 2097152 totalling 2.00MiB
# 2022-08-13 11:54:14.036348: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 4 Chunks of size 2359296 totalling 9.00MiB
# 2022-08-13 11:54:14.036573: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 2405376 totalling 2.29MiB
# 2022-08-13 11:54:14.036819: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 12 Chunks of size 2457600 totalling 28.12MiB
# 2022-08-13 11:54:14.037023: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 4128768 totalling 3.94MiB
# 2022-08-13 11:54:14.037235: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 4718592 totalling 4.50MiB
# 2022-08-13 11:54:14.037447: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 4 Chunks of size 4915200 totalling 18.75MiB
# 2022-08-13 11:54:14.037631: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 6144000 totalling 5.86MiB
# 2022-08-13 11:54:14.037799: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 6758400 totalling 6.45MiB
# 2022-08-13 11:54:14.038003: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 7372800 totalling 7.03MiB
# 2022-08-13 11:54:14.038196: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 7684864 totalling 7.33MiB
# 2022-08-13 11:54:14.038330: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 2 Chunks of size 9437184 totalling 18.00MiB
# 2022-08-13 11:54:14.038433: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 4 Chunks of size 9830400 totalling 37.50MiB
# 2022-08-13 11:54:14.038534: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 10708992 totalling 10.21MiB
# ...
# 2022-08-13 11:54:14.400584: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 45010944 totalling 42.93MiB
# 2022-08-13 11:54:14.400680: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 85234176 totalling 81.29MiB
# 2022-08-13 11:54:14.400791: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 4 Chunks of size 239616000 totalling 914.06MiB
# 2022-08-13 11:54:14.400900: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 250675200 totalling 239.06MiB
# 2022-08-13 11:54:14.400955: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 8 Chunks of size 314572800 totalling 2.34GiB
# 2022-08-13 11:54:14.401079: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 2 Chunks of size 329318400 totalling 628.12MiB
# 2022-08-13 11:54:14.401387: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 340940288 totalling 325.15MiB
# 2022-08-13 11:54:14.401493: I tensorflow/core/common_runtime/bfc_allocator.cc:1072] Sum Total of in-use chunks: 4.76GiB
# 2022-08-13 11:54:14.401590: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] total_region_allocated_bytes_: 5736300544 memory_limit_: 5736300544 available bytes: 0 curr_region_allocation_bytes_: 11472601088
# 2022-08-13 11:54:14.401770: I tensorflow/core/common_runtime/bfc_allocator.cc:1080] Stats:
# Limit:                      5736300544
# InUse:                      5109320960
# MaxInUse:                   5715176192
# NumAllocs:                        7292
# MaxAllocSize:               2980670464
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2022-08-13 11:54:14.402322: W tensorflow/core/common_runtime/bfc_allocator.cc:468] ****___*******___***************************************************__*****************************x
# 2022-08-13 11:54:14.402480: W tensorflow/core/framework/op_kernel.cc:1692] OP_REQUIRES failed at gather_op.cc:158 : Resource exhausted: OOM when allocating tensor with shape[1,1228800,64] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# Traceback (most recent call last):
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\apache_beam\runners\common.py", line 1233, in process
#     return self.do_fn_invoker.invoke_process(windowed_value)
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\apache_beam\runners\common.py", line 572, in invoke_process
#     windowed_value, self.process_method(windowed_value.value))
#   File "c:\Users\victo\Documents\dev\gif_interpolation\frame_interpolation\eval\interpolator_cli.py", line 156, in process
#     frames = list(
#   File "c:\Users\victo\Documents\dev\gif_interpolation\frame_interpolation\eval\util.py", line 178, in interpolate_recursively_from_files
#     yield from _recursive_generator(
#   File "c:\Users\victo\Documents\dev\gif_interpolation\frame_interpolation\eval\util.py", line 149, in _recursive_generator
#     yield from _recursive_generator(frame1, mid_frame, num_recursions - 1,
#   File "c:\Users\victo\Documents\dev\gif_interpolation\frame_interpolation\eval\util.py", line 151, in _recursive_generator
#     yield from _recursive_generator(mid_frame, frame2, num_recursions - 1,
#   File "c:\Users\victo\Documents\dev\gif_interpolation\frame_interpolation\eval\util.py", line 147, in _recursive_generator
#     mid_frame = interpolator.interpolate(
#   File "c:\Users\victo\Documents\dev\gif_interpolation\frame_interpolation\eval\interpolator.py", line 104, in interpolate
#     result = self._model(inputs, training=False)
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\tensorflow\python\saved_model\load.py", line 664, in _call_attribute
#     return instance.__call__(*args, **kwargs)
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\tensorflow\python\eager\def_function.py", line 885, in __call__
#     result = self._call(*args, **kwds)
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\tensorflow\python\eager\def_function.py", line 924, in _call
#     results = self._stateful_fn(*args, **kwds)
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\tensorflow\python\eager\function.py", line 3039, in __call__
#     return graph_function._call_flat(
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\tensorflow\python\eager\function.py", line 1963, in _call_flat
#     return self._build_call_outputs(self._inference_function.call(
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\tensorflow\python\eager\function.py", line 591, in call
#     outputs = execute.execute(
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\tensorflow\python\eager\execute.py", line 59, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.ResourceExhaustedError:  OOM when allocating tensor with shape[1,1228800,64] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node StatefulPartitionedCall/StatefulPartitionedCall/predict_flow/StatefulPartitionedCall/lambda_5/PartitionedCall/dense_image_warp/PartitionedCall/interpolate_bilinear/gather-top_right/GatherV2}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_restored_function_body_13292]
#
# Function call stack:
# restored_function_body
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\victo\Documents\dev\gif_interpolation\frame_interpolation\eval\interpolator_cli.py", line 182, in <module>
#     app.run(main)
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\absl\app.py", line 303, in run
#     _run_main(main, args)
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\absl\app.py", line 251, in _run_main
#     sys.exit(main(argv))
#   File "c:\Users\victo\Documents\dev\gif_interpolation\frame_interpolation\eval\interpolator_cli.py", line 178, in main
#     _run_pipeline()
#   File "c:\Users\victo\Documents\dev\gif_interpolation\frame_interpolation\eval\interpolator_cli.py", line 171, in _run_pipeline
#     result = pipeline.run()
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\apache_beam\pipeline.py", line 573, in run
#     return self.runner.run_pipeline(self, self._options)
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\apache_beam\runners\direct\direct_runner.py", line 131, in run_pipeline
#     return runner.run_pipeline(pipeline, options)
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 195, in run_pipeline
#     self._latest_run_result = self.run_via_runner_api(
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 206, in run_via_runner_api
#     return self.run_stages(stage_context, stages)
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 384, in run_stages
#     stage_results = self._run_stage(
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 646, in _run_stage
#     self._run_bundle(
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 769, in _run_bundle
#     result, splits = bundle_manager.process_bundle(
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 1080, in process_bundle
#     result_future = self._worker_handler.control_conn.push(process_bundle_req)
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\apache_beam\runners\portability\fn_api_runner\worker_handlers.py", line 378, in push
#     response = self.worker.do_instruction(request)
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\apache_beam\runners\worker\sdk_worker.py", line 597, in do_instruction
#     return getattr(self, request_type)(
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\apache_beam\runners\worker\sdk_worker.py", line 635, in process_bundle
#     bundle_processor.process_bundle(instruction_id))
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\apache_beam\runners\worker\bundle_processor.py", line 995, in process_bundle
#     input_op_by_transform_id[element.transform_id].process_encoded(
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\apache_beam\runners\worker\bundle_processor.py", line 221, in process_encoded
#     self.output(decoded_value)
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\apache_beam\runners\worker\operations.py", line 354, in output
#     cython.cast(Receiver, self.receivers[output_index]).receive(windowed_value)
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\apache_beam\runners\worker\operations.py", line 216, in receive
#     self.consumer.process(windowed_value)
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\apache_beam\runners\worker\operations.py", line 714, in process
#     delayed_applications = self.dofn_runner.process(o)
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\apache_beam\runners\common.py", line 1235, in process
#     self._reraise_augmented(exn)
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\apache_beam\runners\common.py", line 1233, in process
#     return self.do_fn_invoker.invoke_process(windowed_value)
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\apache_beam\runners\common.py", line 571, in invoke_process
#     self.output_processor.process_outputs(
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\apache_beam\runners\common.py", line 1396, in process_outputs
#     self.main_receivers.receive(windowed_value)
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\apache_beam\runners\worker\operations.py", line 216, in receive
#     self.consumer.process(windowed_value)
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\apache_beam\runners\worker\operations.py", line 714, in process
#     delayed_applications = self.dofn_runner.process(o)
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\apache_beam\runners\common.py", line 1235, in process
#     self._reraise_augmented(exn)
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\apache_beam\runners\common.py", line 1233, in process
#     return self.do_fn_invoker.invoke_process(windowed_value)
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\apache_beam\runners\common.py", line 571, in invoke_process
#     self.output_processor.process_outputs(
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\apache_beam\runners\common.py", line 1396, in process_outputs
#     self.main_receivers.receive(windowed_value)
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\apache_beam\runners\worker\operations.py", line 216, in receive
#     self.consumer.process(windowed_value)
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\apache_beam\runners\worker\operations.py", line 714, in process
#     delayed_applications = self.dofn_runner.process(o)
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\apache_beam\runners\common.py", line 1235, in process
#     self._reraise_augmented(exn)
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\apache_beam\runners\common.py", line 1316, in _reraise_augmented
#     raise new_exn.with_traceback(tb)
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\apache_beam\runners\common.py", line 1233, in process
#     return self.do_fn_invoker.invoke_process(windowed_value)
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\apache_beam\runners\common.py", line 572, in invoke_process
#     windowed_value, self.process_method(windowed_value.value))
#   File "c:\Users\victo\Documents\dev\gif_interpolation\frame_interpolation\eval\interpolator_cli.py", line 156, in process
#     frames = list(
#   File "c:\Users\victo\Documents\dev\gif_interpolation\frame_interpolation\eval\util.py", line 178, in interpolate_recursively_from_files
#     yield from _recursive_generator(
#   File "c:\Users\victo\Documents\dev\gif_interpolation\frame_interpolation\eval\util.py", line 149, in _recursive_generator
#     yield from _recursive_generator(frame1, mid_frame, num_recursions - 1,
#   File "c:\Users\victo\Documents\dev\gif_interpolation\frame_interpolation\eval\util.py", line 151, in _recursive_generator
#     yield from _recursive_generator(mid_frame, frame2, num_recursions - 1,
#   File "c:\Users\victo\Documents\dev\gif_interpolation\frame_interpolation\eval\util.py", line 147, in _recursive_generator
#     mid_frame = interpolator.interpolate(
#   File "c:\Users\victo\Documents\dev\gif_interpolation\frame_interpolation\eval\interpolator.py", line 104, in interpolate
#     result = self._model(inputs, training=False)
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\tensorflow\python\saved_model\load.py", line 664, in _call_attribute
#     return instance.__call__(*args, **kwargs)
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\tensorflow\python\eager\def_function.py", line 885, in __call__
#     result = self._call(*args, **kwds)
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\tensorflow\python\eager\def_function.py", line 924, in _call
#     results = self._stateful_fn(*args, **kwds)
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\tensorflow\python\eager\function.py", line 3039, in __call__
#     return graph_function._call_flat(
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\tensorflow\python\eager\function.py", line 1963, in _call_flat
#     return self._build_call_outputs(self._inference_function.call(
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\tensorflow\python\eager\function.py", line 591, in call
#     outputs = execute.execute(
#   File "c:\Users\victo\anaconda3\envs\frame_interpolation\lib\site-packages\tensorflow\python\eager\execute.py", line 59, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# RuntimeError: tensorflow.python.framework.errors_impl.ResourceExhaustedError:  OOM when allocating tensor with shape[1,1228800,64] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node StatefulPartitionedCall/StatefulPartitionedCall/predict_flow/StatefulPartitionedCall/lambda_5/PartitionedCall/dense_image_warp/PartitionedCall/interpolate_bilinear/gather-top_right/GatherV2}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_restored_function_body_13292]
#
# Function call stack:
# restored_function_body [while running 'Process directories']

# %%
# create boomerang

# !ffmpeg -y -i {folder}/interpolated.mp4 \
        -filter_complex "[0]reverse[r];[0][r]concat=n=2:v=1:a=0,split[s0][s1];[s0]palettegen[p];[s1][p]paletteuse" \
        {folder}/interpolated.gif
# Out:
# ffmpeg version 5.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with clang version 14.0.6
#   configuration: --prefix=/d/bld/ffmpeg_1658802367738/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libfontconfig --enable-libopenh264 --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --pkg-config=/d/bld/ffmpeg_1658802367738/_build_env/Library/bin/pkg-config
#   libavutil      57. 28.100 / 57. 28.100
#   libavcodec     59. 37.100 / 59. 37.100
#   libavformat    59. 27.100 / 59. 27.100
#   libavdevice    59.  7.100 / 59.  7.100
#   libavfilter     8. 44.100 /  8. 44.100
#   libswscale      6.  7.100 /  6.  7.100
#   libswresample   4.  7.100 /  4.  7.100
#   libpostproc    56.  6.100 / 56.  6.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'photos/interpolated.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:00.57, start: 0.000000, bitrate: 1534 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), yuv444p(progressive), 700x933, 1520 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.37.100 libx264
# Stream mapping:
#   Stream #0:0 (h264) -> reverse:default
#   Stream #0:0 (h264) -> concat
#   paletteuse:default -> Stream #0:0 (gif)
# Press [q] to stop, [?] for help
# [Parsed_palettegen_3 @ 000002311F1E3EC0] 255(+1) colors generated out of 86231 colors; ratio=0.002957
# Output #0, gif, to 'photos/interpolated.gif':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.27.100
#   Stream #0:0: Video: gif, pal8(pc, gbr/unknown/unknown, progressive), 700x933, q=2-31, 200 kb/s, 30 fps, 100 tbn
#     Metadata:
#       encoder         : Lavc59.37.100 gif
# frame=    2 fps=0.0 q=-0.0 size=     256kB time=00:00:00.04 bitrate=52428.8kbits/s speed=0.0678x
# frame=    8 fps=6.9 q=-0.0 size=    2048kB time=00:00:00.24 bitrate=69905.1kbits/s speed=0.208x
# frame=   14 fps=8.2 q=-0.0 size=    3840kB time=00:00:00.44 bitrate=71493.8kbits/s speed=0.258x
# frame=   19 fps=8.5 q=-0.0 size=    5120kB time=00:00:00.61 bitrate=68759.1kbits/s speed=0.274x
# frame=   28 fps= 10 q=-0.0 size=    7680kB time=00:00:00.91 bitrate=69136.9kbits/s speed=0.328x
# frame=   34 fps= 10 q=-0.0 size=    9728kB time=00:00:01.11 bitrate=71794.4kbits/s speed=0.338x
# frame=   34 fps= 10 q=-0.0 Lsize=   10046kB time=00:00:01.11 bitrate=74137.7kbits/s speed=0.338x
# video:10045kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000194%
